# %% [markdown]
# <a href="https://colab.research.google.com/github/ranadeepbhuyan/cancer-mri-analysis/blob/main/stateOfArt/DUCK_with_IEG_modified.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import nibabel as nib
import os
import nibabel as nib

# %%
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Data_path = r"/content/drive/MyDrive/PKG - UPENN-GBM NIfTI files/NIfTI-files/images_structural" +"/"

# %%
Mask_path = r"/content/drive/MyDrive/PKG - UPENN-GBM NIfTI files/NIfTI-files/automated_segm" +"/"

# %%
#fatching ids form data path
def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x


train_data_ids = [f.path for f in os.scandir(Data_path)]

training_data_ids = pathListIntoIds(train_data_ids);

# %%
mask_data_ids = [f.path for f in os.scandir(Mask_path)]

mask_ids = pathListIntoIds(mask_data_ids);

# %%
mask_ids.sort()
training_data_ids.sort()

# %%
ids = []
for i in range(len(mask_ids)):
  test = mask_ids[i].split('_automated_approx_segm.nii')[0]
  ids.append(test)

# %%
data_ids = []
for i in range(len(ids)):
  if ids[i] in training_data_ids:
    data_ids.append(ids[i])

# %%
len(data_ids)
# Out:
# 611

# %%
only = []
for i in range(0,10):
  only.append(data_ids[i])

# %%
train_test_ids, val_ids = train_test_split(only,test_size=0.2)
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
VOLUME_SLICES = 10
IMG_SIZE = 128
required_shape = (IMG_SIZE,IMG_SIZE,IMG_SIZE)

# %%
def add_padding(img_data, required_shape):
    # Ensure the dimensions of required_shape are (height, width, channels)
    required_height, required_width, required_length = required_shape

    # Calculate the amount of padding required on each side
    pad_x = required_height - img_data.shape[0]
    pad_y = required_width - img_data.shape[1]
    pad_z = required_length - img_data.shape[2]
    # Check if padding is needed
    if pad_x > 0 or pad_y > 0 or pad_z>0 :
        # Calculate the padding values for the top, bottom, left, and right sides
        pad_top = max(pad_x // 2, 0)
        pad_bottom = pad_x - pad_top
        pad_left = max(pad_y // 2, 0)
        pad_right = pad_y - pad_left
        pad_up = max(pad_z // 2, 0)
        pad_down = pad_z - pad_up

        # Create an empty array with the required shape
        padded_data = np.zeros((required_height, required_width, required_length), dtype=img_data.dtype)

        # Copy the original image data into the center of the padded array
        padded_data[pad_top:pad_top+img_data.shape[0], pad_left:pad_left+img_data.shape[1],pad_up:pad_up+img_data.shape[2]] = img_data
    else:
        # No padding needed; return the original image
        padded_data = img_data

    return padded_data

# %%
data_path1 = os.path.join(Data_path, f'{data_ids[100]}/{data_ids[100]}_T1GD.nii');
t1gd_data = nib.load(data_path1).get_fdata()

data_path1 = os.path.join(Mask_path, f'{data_ids[0]}_automated_approx_segm.nii');
seg_data = nib.load(data_path1).get_fdata()

# %%
# Function to display slices of the 3D image
def show_slices(image):
    # Calculate the middle index along the first axis
    middle_slice_index = image.shape[0] // 2

    # Plot the slices along the first axis
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    axes[0].imshow(cv2.resize(image[middle_slice_index, :, :], (128, 128), interpolation=cv2.INTER_LINEAR), cmap='gray')
    axes[0].set_title('Slice along axis 0')

    # Plot the slices along the second axis
    axes[1].imshow(cv2.resize(image[:, middle_slice_index, :], (128, 128), interpolation=cv2.INTER_LINEAR), cmap='gray')
    axes[1].set_title('Slice along axis 1')

    # Plot the slices along the third axis
    axes[2].imshow(cv2.resize(image[:, :, middle_slice_index], (128, 128), interpolation=cv2.INTER_LINEAR), cmap='gray')
    axes[2].set_title('Slice along axis 2')

    # Display the plots
    plt.show()

# Display slices of the 3D image
show_slices(t1gd_data)

# %%
show_slices(seg_data)

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 3, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim))
              # Generate data
        for c, i in enumerate(Batch_ids):
            data_path1 = os.path.join(Data_path, f'{i}/{i}_FLAIR.nii');
            flair_data = nib.load(data_path1).get_fdata()
            flair = add_padding(flair_data, required_shape)

            data_path1 = os.path.join(Data_path, f'{i}/{i}_T1GD.nii');
            t1gd_data = nib.load(data_path1).get_fdata()
            t1gd = add_padding(t1gd_data, required_shape)

            data_path1 =  os.path.join(Data_path, f'{i}/{i}_T2.nii');
            t2_data = nib.load(data_path1).get_fdata()
            t2 = add_padding(t2_data, required_shape)

            data_path1 = os.path.join(Mask_path, f'{i}_automated_approx_segm.nii');
            seg_data = nib.load(data_path1).get_fdata()
            seg = add_padding(seg_data, required_shape)

            slice_w = 25

            for j in range(VOLUME_SLICES):
                X[j +VOLUME_SLICES*c,:,:,:,0] = cv2.resize(flair[:,:,flair.shape[0]//4 +j*5], (IMG_SIZE, IMG_SIZE));
                X[j +VOLUME_SLICES*c,:,:,:,1] = cv2.resize(t1gd[:,:,t1gd.shape[0]//4 +j*5], (IMG_SIZE, IMG_SIZE));
                X[j +VOLUME_SLICES*c,:,:,:,2] = cv2.resize(t2[:,:,t2.shape[0]//4 +j*5], (IMG_SIZE, IMG_SIZE));

                Y[j +VOLUME_SLICES*c,:,:,:] = cv2.resize(seg[:,:,seg.shape[0]//4 +j*5], (IMG_SIZE, IMG_SIZE));


        Y[Y==4] = 3;
        mask = tf.one_hot(Y, 4);

        return X/np.max(X), mask

# %%
training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
def residual_block(input,nfilters):
  conv1 = Conv3D(filters=nfilters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal')(input)
  conv1 = BatchNormalization()(conv1)
  conv2 = Conv3D(filters=nfilters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal')(conv1)
  conv2 = BatchNormalization()(conv2)

  conv3 = Conv3D(filters=nfilters, kernel_size=(1, 1, 1), padding='same', kernel_initializer='he_normal')(input)
  conv3 = BatchNormalization()(conv3)

  y = Add()([conv2, conv3])
  y = BatchNormalization()(y)

  return y

# %%
def midscope_block(input,nfilters):
  conv1 = Conv3D(filters=nfilters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal')(input)
  conv1 = BatchNormalization()(conv1)
  conv2 = Conv3D(filters=nfilters, kernel_size=(3, 3, 3),dilation_rate=(2, 2, 2), padding='same', kernel_initializer='he_normal')(conv1)
  conv2 = BatchNormalization()(conv2)

  return conv2

# %%
def widescope_block(input,nfilters):
  conv1 = Conv3D(filters=nfilters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal')(input)
  conv1 = BatchNormalization()(conv1)
  conv2 = Conv3D(filters=nfilters, kernel_size=(3, 3, 3),dilation_rate=(2, 2, 2), padding='same', kernel_initializer='he_normal')(conv1)
  conv2 = BatchNormalization()(conv2)
  conv3 = Conv3D(filters=nfilters, kernel_size=(3, 3, 3),dilation_rate=(3, 3, 3), padding='same', kernel_initializer='he_normal')(conv2)
  conv3 = BatchNormalization()(conv3)

  return conv3

# %%
def Separated_block(input, nfilters, n):
  conv1 = Conv3D(filters=nfilters, kernel_size=(1, 1, n), padding='same', kernel_initializer='he_normal')(input)
  conv1 = BatchNormalization()(conv1)
  conv2 = Conv3D(filters=nfilters, kernel_size=(1, n, 1), padding='same', kernel_initializer='he_normal')(conv1)
  conv2 = BatchNormalization()(conv2)
  conv3 = Conv3D(filters=nfilters, kernel_size=(n, 1, 1), padding='same', kernel_initializer='he_normal')(conv2)
  conv3 = BatchNormalization()(conv3)

  return conv3

# %%
def IEG(input, nfilters):
  conv1 = Conv3D(filters=nfilters, kernel_size=(3, 3, 3),dilation_rate=(1, 1, 1), padding='same', kernel_initializer='he_normal')(input)
  conv1 = BatchNormalization()(conv1)
  conv2 = Conv3D(filters=nfilters, kernel_size=(3, 3, 3),dilation_rate=(1, 1, 1), padding='same', kernel_initializer='he_normal')(conv1)

  conv3 = Conv3D(filters=nfilters, kernel_size=(3, 3, 3),dilation_rate=(1, 1, 1), padding='same', kernel_initializer='he_normal')(input)
  conv3 = BatchNormalization()(conv3)

  add_conv = Add()([conv2, conv3])

  return add_conv

# %%
def duck_block(input,nfilters):

  norml = BatchNormalization()(input,nfilters)
  widblck = widescope_block(norml,nfilters)
  #midblck = midscope_block(norml,nfilters)

  #resblck1 = residual_block(norml,nfilters)

  #resblck2 = residual_block(norml,nfilters)
  #resblck3 = residual_block(resblck2,nfilters)

  #addblck = Add()([resblck1, resblck3])

  IEG_block1 = IEG(norml, nfilters)
  IEG_block2 = IEG(IEG_block1, nfilters)
  IEG_block3 = IEG(IEG_block2, nfilters)

  #sepblck = Separated_block(norml,nfilters,6)

  addblck2 = Add()([widblck, IEG_block3])

  #addblck3 = Add()([addblck2, addblck])

  #addblck4 = Add()([addblck3, IEG_block3])

  #addblck5 = Add()([addblck, sepblck])

  output = BatchNormalization()(addblck2)

  return output

# %% [markdown]
# Model Architecture:
#
#
# ![WhatsApp Image 2024-03-06 at 12.48.24 PM.jpg](data:image/jpeg;base64,...)![WhatsApp Image 2024-03-11 at 1.10.59 PM (1).jpg](data:image/jpeg;base64,...)

# %%
def DUCK_with_IEG_modified(img_height, img_width, img_length, nclasses=None):

    def encoder_block2(input_tensor, nfilters):

        x = Conv3D(filters=nfilters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal')(input_tensor)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling3D(pool_size=(2, 2, 2))(x)
        return x


    def decoder_block(input_tensor, nfilters):

        x = Conv3DTranspose(filters=nfilters, kernel_size=(3, 3, 3), strides=(2, 2, 2), padding='same', kernel_initializer='he_normal')(input_tensor)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        return x

    # f is number of filters
    f = 4
    #initial block
    input_layer = Input(shape=(img_height, img_width, img_length, 3))

    ducky = duck_block(input_layer, f)

    # 1st encoder
    #encoder_1 = encoder_block2(input_layer, f*2)
    #encoder_duck_1 = encoder_block2(ducky, f*2)
    #encoder_add_1 = Add()([encoder_1, encoder_duck_1])

    # 2nd encoder
    encoder_2 = encoder_block2(input_layer, f*2)
    encoder_duck_2 = encoder_block2(ducky, f*2)
    encoder_add_2 = Add()([encoder_2, encoder_duck_2])

    # 3rd encoder
    encoder_3 = encoder_block2(encoder_2, f*4)
    encoder_duck_3 = encoder_block2(encoder_duck_2, f*4)
    encoder_add_3 = Add()([encoder_3, encoder_duck_3])
    encoder_duck_add_3 = duck_block(encoder_add_3, f*4)

    # 4th encoder
    encoder_4 = encoder_block2(encoder_3, f*8)
    encoder_duck_4 = encoder_block2(encoder_duck_add_3, f*8)
    encoder_add_4 = Add()([encoder_4, encoder_duck_4])
    encoder_duck_add_4 = duck_block(encoder_add_4, f*8)

    #bottom layer
    bottom_layer1 = encoder_block2(encoder_4, f*16)
    bottom_layer2 = encoder_block2(encoder_duck_add_4, f*16)
    bottom_layer = Add()([bottom_layer1, bottom_layer2])
    resblock1 = residual_block(bottom_layer, f*8)
    resblock2 = residual_block(resblock1, f*8)

    #4th decode
    decode_4 = decoder_block(resblock2, f*8)
    decode_add_4 = Add()([decode_4, encoder_duck_add_4])
    decode_duck_4 = duck_block(decode_add_4, f*4)

    #3rd decode
    decode_3 = decoder_block(decode_duck_4, f*4)
    decode_add_3 = Add()([decode_3, encoder_duck_add_3])
    decode_duck_3 = duck_block(decode_add_3, f*2)

    #2nd decode
    decode_2 = decoder_block(decode_duck_3, f*2)
    decode_IEG1_2 = IEG(encoder_add_2, f*2)
    decode_add_2 = Add()([decode_2, decode_IEG1_2])
    decode_IEG2_2 = IEG(decode_add_2, f)

    #1st decode
    #decode_1 = decoder_block(decode_duck_3, f*2)
    #decode_IEG1_1 = IEG(encoder_add_1, f*2)
    #decode_add_1 = Add()([decode_1, decode_IEG1_1])
    #decode_IEG2_1 = IEG(decode_add_1, f)

    #final layer
    final_layer = decoder_block(decode_IEG2_2, f)
    final_layer_add = Add()([final_layer, ducky])
    final_layer_duck = duck_block(final_layer_add, f)

    final_output = Conv3DTranspose(filters=nclasses, kernel_size=(1, 1, 1), padding='same', kernel_initializer='he_normal')(final_layer_duck)

    output_layer = Activation('softmax')(final_output)

    model = Model(inputs=input_layer, outputs=output_layer, name='DUCK_with_IEG_MODIFIED')
    return model

# %%
# dice loss as defined above for 4 classes
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss

    total_loss = total_loss / class_num
    return total_loss

# %%
def mean_iou(y_true, y_pred, smooth=1.0):
    class_num = 4
    iou_total = 0

    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,:,i])

        intersection = K.sum(K.abs(y_true_f * y_pred_f))
        union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection

        iou = (intersection + smooth) / (union + smooth)
        iou_total += iou

    mean_iou = iou_total / class_num
    return mean_iou

# %%
model = DUCK_with_IEG_modified(IMG_SIZE, IMG_SIZE, IMG_SIZE, nclasses=4)
model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',mean_iou, dice_coef] )

# %%
model.summary()
# Out:
# Model: "DUCK_with_IEG_MODIFIED"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  batch_normalization_76 (BatchN  (None, 128, 128, 12  12         ['input_2[0][0]']
#  ormalization)                  8, 3)
#
#  conv3d_80 (Conv3D)             (None, 128, 128, 12  328         ['batch_normalization_76[0][0]']
#                                 8, 4)
#
#  batch_normalization_80 (BatchN  (None, 128, 128, 12  16         ['conv3d_80[0][0]']
#  ormalization)                  8, 4)
#
#  conv3d_82 (Conv3D)             (None, 128, 128, 12  328         ['batch_normalization_76[0][0]']
#                                 8, 4)
#
#  conv3d_81 (Conv3D)             (None, 128, 128, 12  436         ['batch_normalization_80[0][0]']
#                                 8, 4)
#
#  batch_normalization_81 (BatchN  (None, 128, 128, 12  16         ['conv3d_82[0][0]']
#  ormalization)                  8, 4)
#
#  add_30 (Add)                   (None, 128, 128, 12  0           ['conv3d_81[0][0]',
#                                 8, 4)                             'batch_normalization_81[0][0]']
#
#  conv3d_83 (Conv3D)             (None, 128, 128, 12  436         ['add_30[0][0]']
#                                 8, 4)
#
#  batch_normalization_82 (BatchN  (None, 128, 128, 12  16         ['conv3d_83[0][0]']
#  ormalization)                  8, 4)
#
#  conv3d_85 (Conv3D)             (None, 128, 128, 12  436         ['add_30[0][0]']
#                                 8, 4)
#
#  conv3d_77 (Conv3D)             (None, 128, 128, 12  328         ['batch_normalization_76[0][0]']
#                                 8, 4)
#
#  conv3d_84 (Conv3D)             (None, 128, 128, 12  436         ['batch_normalization_82[0][0]']
#                                 8, 4)
#
#  batch_normalization_83 (BatchN  (None, 128, 128, 12  16         ['conv3d_85[0][0]']
#  ormalization)                  8, 4)
#
#  batch_normalization_77 (BatchN  (None, 128, 128, 12  16         ['conv3d_77[0][0]']
#  ormalization)                  8, 4)
#
#  add_31 (Add)                   (None, 128, 128, 12  0           ['conv3d_84[0][0]',
#                                 8, 4)                             'batch_normalization_83[0][0]']
#
#  conv3d_78 (Conv3D)             (None, 128, 128, 12  436         ['batch_normalization_77[0][0]']
#                                 8, 4)
#
#  conv3d_86 (Conv3D)             (None, 128, 128, 12  436         ['add_31[0][0]']
#                                 8, 4)
#
#  batch_normalization_78 (BatchN  (None, 128, 128, 12  16         ['conv3d_78[0][0]']
#  ormalization)                  8, 4)
#
#  batch_normalization_84 (BatchN  (None, 128, 128, 12  16         ['conv3d_86[0][0]']
#  ormalization)                  8, 4)
#
#  conv3d_88 (Conv3D)             (None, 128, 128, 12  436         ['add_31[0][0]']
#                                 8, 4)
#
#  conv3d_79 (Conv3D)             (None, 128, 128, 12  436         ['batch_normalization_78[0][0]']
#                                 8, 4)
#
#  conv3d_87 (Conv3D)             (None, 128, 128, 12  436         ['batch_normalization_84[0][0]']
#                                 8, 4)
#
#  batch_normalization_85 (BatchN  (None, 128, 128, 12  16         ['conv3d_88[0][0]']
#  ormalization)                  8, 4)
#
#  batch_normalization_79 (BatchN  (None, 128, 128, 12  16         ['conv3d_79[0][0]']
#  ormalization)                  8, 4)
#
#  add_32 (Add)                   (None, 128, 128, 12  0           ['conv3d_87[0][0]',
#                                 8, 4)                             'batch_normalization_85[0][0]']
#
#  add_33 (Add)                   (None, 128, 128, 12  0           ['batch_normalization_79[0][0]',
#                                 8, 4)                             'add_32[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 128, 128, 12  16         ['add_33[0][0]']
#  ormalization)                  8, 4)
#
#  conv3d_89 (Conv3D)             (None, 128, 128, 12  656         ['input_2[0][0]']
#                                 8, 8)
#
#  conv3d_90 (Conv3D)             (None, 128, 128, 12  872         ['batch_normalization_86[0][0]']
#                                 8, 8)
#
#  batch_normalization_87 (BatchN  (None, 128, 128, 12  32         ['conv3d_89[0][0]']
#  ormalization)                  8, 8)
#
#  batch_normalization_88 (BatchN  (None, 128, 128, 12  32         ['conv3d_90[0][0]']
#  ormalization)                  8, 8)
#
#  activation_11 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_87[0][0]']
#                                 8, 8)
#
#  activation_12 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_88[0][0]']
#                                 8, 8)
#
#  max_pooling3d_8 (MaxPooling3D)  (None, 64, 64, 64,   0          ['activation_11[0][0]']
#                                 8)
#
#  max_pooling3d_9 (MaxPooling3D)  (None, 64, 64, 64,   0          ['activation_12[0][0]']
#                                 8)
#
#  conv3d_91 (Conv3D)             (None, 64, 64, 64,   3472        ['max_pooling3d_8[0][0]']
#                                 16)
#
#  conv3d_92 (Conv3D)             (None, 64, 64, 64,   3472        ['max_pooling3d_9[0][0]']
#                                 16)
#
#  batch_normalization_89 (BatchN  (None, 64, 64, 64,   64         ['conv3d_91[0][0]']
#  ormalization)                  16)
#
#  batch_normalization_90 (BatchN  (None, 64, 64, 64,   64         ['conv3d_92[0][0]']
#  ormalization)                  16)
#
#  activation_13 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_89[0][0]']
#                                 16)
#
#  activation_14 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_90[0][0]']
#                                 16)
#
#  max_pooling3d_10 (MaxPooling3D  (None, 32, 32, 32,   0          ['activation_13[0][0]']
#  )                              16)
#
#  max_pooling3d_11 (MaxPooling3D  (None, 32, 32, 32,   0          ['activation_14[0][0]']
#  )                              16)
#
#  add_35 (Add)                   (None, 32, 32, 32,   0           ['max_pooling3d_10[0][0]',
#                                 16)                               'max_pooling3d_11[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 32, 32, 32,   64         ['add_35[0][0]']
#  ormalization)                  16)
#
#  conv3d_96 (Conv3D)             (None, 32, 32, 32,   6928        ['batch_normalization_91[0][0]']
#                                 16)
#
#  batch_normalization_95 (BatchN  (None, 32, 32, 32,   64         ['conv3d_96[0][0]']
#  ormalization)                  16)
#
#  conv3d_98 (Conv3D)             (None, 32, 32, 32,   6928        ['batch_normalization_91[0][0]']
#                                 16)
#
#  conv3d_97 (Conv3D)             (None, 32, 32, 32,   6928        ['batch_normalization_95[0][0]']
#                                 16)
#
#  batch_normalization_96 (BatchN  (None, 32, 32, 32,   64         ['conv3d_98[0][0]']
#  ormalization)                  16)
#
#  add_36 (Add)                   (None, 32, 32, 32,   0           ['conv3d_97[0][0]',
#                                 16)                               'batch_normalization_96[0][0]']
#
#  conv3d_99 (Conv3D)             (None, 32, 32, 32,   6928        ['add_36[0][0]']
#                                 16)
#
#  batch_normalization_97 (BatchN  (None, 32, 32, 32,   64         ['conv3d_99[0][0]']
#  ormalization)                  16)
#
#  conv3d_101 (Conv3D)            (None, 32, 32, 32,   6928        ['add_36[0][0]']
#                                 16)
#
#  conv3d_93 (Conv3D)             (None, 32, 32, 32,   6928        ['batch_normalization_91[0][0]']
#                                 16)
#
#  conv3d_100 (Conv3D)            (None, 32, 32, 32,   6928        ['batch_normalization_97[0][0]']
#                                 16)
#
#  batch_normalization_98 (BatchN  (None, 32, 32, 32,   64         ['conv3d_101[0][0]']
#  ormalization)                  16)
#
#  batch_normalization_92 (BatchN  (None, 32, 32, 32,   64         ['conv3d_93[0][0]']
#  ormalization)                  16)
#
#  add_37 (Add)                   (None, 32, 32, 32,   0           ['conv3d_100[0][0]',
#                                 16)                               'batch_normalization_98[0][0]']
#
#  conv3d_94 (Conv3D)             (None, 32, 32, 32,   6928        ['batch_normalization_92[0][0]']
#                                 16)
#
#  conv3d_102 (Conv3D)            (None, 32, 32, 32,   6928        ['add_37[0][0]']
#                                 16)
#
#  batch_normalization_93 (BatchN  (None, 32, 32, 32,   64         ['conv3d_94[0][0]']
#  ormalization)                  16)
#
#  batch_normalization_99 (BatchN  (None, 32, 32, 32,   64         ['conv3d_102[0][0]']
#  ormalization)                  16)
#
#  conv3d_104 (Conv3D)            (None, 32, 32, 32,   6928        ['add_37[0][0]']
#                                 16)
#
#  conv3d_95 (Conv3D)             (None, 32, 32, 32,   6928        ['batch_normalization_93[0][0]']
#                                 16)
#
#  conv3d_103 (Conv3D)            (None, 32, 32, 32,   6928        ['batch_normalization_99[0][0]']
#                                 16)
#
#  batch_normalization_100 (Batch  (None, 32, 32, 32,   64         ['conv3d_104[0][0]']
#  Normalization)                 16)
#
#  batch_normalization_94 (BatchN  (None, 32, 32, 32,   64         ['conv3d_95[0][0]']
#  ormalization)                  16)
#
#  add_38 (Add)                   (None, 32, 32, 32,   0           ['conv3d_103[0][0]',
#                                 16)                               'batch_normalization_100[0][0]']
#
#  add_39 (Add)                   (None, 32, 32, 32,   0           ['batch_normalization_94[0][0]',
#                                 16)                               'add_38[0][0]']
#
#  batch_normalization_101 (Batch  (None, 32, 32, 32,   64         ['add_39[0][0]']
#  Normalization)                 16)
#
#  conv3d_105 (Conv3D)            (None, 32, 32, 32,   13856       ['max_pooling3d_10[0][0]']
#                                 32)
#
#  conv3d_106 (Conv3D)            (None, 32, 32, 32,   13856       ['batch_normalization_101[0][0]']
#                                 32)
#
#  batch_normalization_102 (Batch  (None, 32, 32, 32,   128        ['conv3d_105[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_103 (Batch  (None, 32, 32, 32,   128        ['conv3d_106[0][0]']
#  Normalization)                 32)
#
#  activation_15 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_102[0][0]']
#                                 32)
#
#  activation_16 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_103[0][0]']
#                                 32)
#
#  max_pooling3d_12 (MaxPooling3D  (None, 16, 16, 16,   0          ['activation_15[0][0]']
#  )                              32)
#
#  max_pooling3d_13 (MaxPooling3D  (None, 16, 16, 16,   0          ['activation_16[0][0]']
#  )                              32)
#
#  add_40 (Add)                   (None, 16, 16, 16,   0           ['max_pooling3d_12[0][0]',
#                                 32)                               'max_pooling3d_13[0][0]']
#
#  batch_normalization_104 (Batch  (None, 16, 16, 16,   128        ['add_40[0][0]']
#  Normalization)                 32)
#
#  conv3d_110 (Conv3D)            (None, 16, 16, 16,   27680       ['batch_normalization_104[0][0]']
#                                 32)
#
#  batch_normalization_108 (Batch  (None, 16, 16, 16,   128        ['conv3d_110[0][0]']
#  Normalization)                 32)
#
#  conv3d_112 (Conv3D)            (None, 16, 16, 16,   27680       ['batch_normalization_104[0][0]']
#                                 32)
#
#  conv3d_111 (Conv3D)            (None, 16, 16, 16,   27680       ['batch_normalization_108[0][0]']
#                                 32)
#
#  batch_normalization_109 (Batch  (None, 16, 16, 16,   128        ['conv3d_112[0][0]']
#  Normalization)                 32)
#
#  add_41 (Add)                   (None, 16, 16, 16,   0           ['conv3d_111[0][0]',
#                                 32)                               'batch_normalization_109[0][0]']
#
#  conv3d_113 (Conv3D)            (None, 16, 16, 16,   27680       ['add_41[0][0]']
#                                 32)
#
#  batch_normalization_110 (Batch  (None, 16, 16, 16,   128        ['conv3d_113[0][0]']
#  Normalization)                 32)
#
#  conv3d_115 (Conv3D)            (None, 16, 16, 16,   27680       ['add_41[0][0]']
#                                 32)
#
#  conv3d_107 (Conv3D)            (None, 16, 16, 16,   27680       ['batch_normalization_104[0][0]']
#                                 32)
#
#  conv3d_114 (Conv3D)            (None, 16, 16, 16,   27680       ['batch_normalization_110[0][0]']
#                                 32)
#
#  batch_normalization_111 (Batch  (None, 16, 16, 16,   128        ['conv3d_115[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_105 (Batch  (None, 16, 16, 16,   128        ['conv3d_107[0][0]']
#  Normalization)                 32)
#
#  add_42 (Add)                   (None, 16, 16, 16,   0           ['conv3d_114[0][0]',
#                                 32)                               'batch_normalization_111[0][0]']
#
#  conv3d_108 (Conv3D)            (None, 16, 16, 16,   27680       ['batch_normalization_105[0][0]']
#                                 32)
#
#  conv3d_116 (Conv3D)            (None, 16, 16, 16,   27680       ['add_42[0][0]']
#                                 32)
#
#  batch_normalization_106 (Batch  (None, 16, 16, 16,   128        ['conv3d_108[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_112 (Batch  (None, 16, 16, 16,   128        ['conv3d_116[0][0]']
#  Normalization)                 32)
#
#  conv3d_118 (Conv3D)            (None, 16, 16, 16,   27680       ['add_42[0][0]']
#                                 32)
#
#  conv3d_109 (Conv3D)            (None, 16, 16, 16,   27680       ['batch_normalization_106[0][0]']
#                                 32)
#
#  conv3d_117 (Conv3D)            (None, 16, 16, 16,   27680       ['batch_normalization_112[0][0]']
#                                 32)
#
#  batch_normalization_113 (Batch  (None, 16, 16, 16,   128        ['conv3d_118[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_107 (Batch  (None, 16, 16, 16,   128        ['conv3d_109[0][0]']
#  Normalization)                 32)
#
#  add_43 (Add)                   (None, 16, 16, 16,   0           ['conv3d_117[0][0]',
#                                 32)                               'batch_normalization_113[0][0]']
#
#  add_44 (Add)                   (None, 16, 16, 16,   0           ['batch_normalization_107[0][0]',
#                                 32)                               'add_43[0][0]']
#
#  batch_normalization_114 (Batch  (None, 16, 16, 16,   128        ['add_44[0][0]']
#  Normalization)                 32)
#
#  conv3d_119 (Conv3D)            (None, 16, 16, 16,   55360       ['max_pooling3d_12[0][0]']
#                                 64)
#
#  conv3d_120 (Conv3D)            (None, 16, 16, 16,   55360       ['batch_normalization_114[0][0]']
#                                 64)
#
#  batch_normalization_115 (Batch  (None, 16, 16, 16,   256        ['conv3d_119[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_116 (Batch  (None, 16, 16, 16,   256        ['conv3d_120[0][0]']
#  Normalization)                 64)
#
#  activation_17 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_115[0][0]']
#                                 64)
#
#  activation_18 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_116[0][0]']
#                                 64)
#
#  max_pooling3d_14 (MaxPooling3D  (None, 8, 8, 8, 64)  0          ['activation_17[0][0]']
#  )
#
#  max_pooling3d_15 (MaxPooling3D  (None, 8, 8, 8, 64)  0          ['activation_18[0][0]']
#  )
#
#  add_45 (Add)                   (None, 8, 8, 8, 64)  0           ['max_pooling3d_14[0][0]',
#                                                                   'max_pooling3d_15[0][0]']
#
#  conv3d_121 (Conv3D)            (None, 8, 8, 8, 32)  55328       ['add_45[0][0]']
#
#  batch_normalization_117 (Batch  (None, 8, 8, 8, 32)  128        ['conv3d_121[0][0]']
#  Normalization)
#
#  conv3d_122 (Conv3D)            (None, 8, 8, 8, 32)  27680       ['batch_normalization_117[0][0]']
#
#  conv3d_123 (Conv3D)            (None, 8, 8, 8, 32)  2080        ['add_45[0][0]']
#
#  batch_normalization_118 (Batch  (None, 8, 8, 8, 32)  128        ['conv3d_122[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 8, 8, 8, 32)  128        ['conv3d_123[0][0]']
#  Normalization)
#
#  add_46 (Add)                   (None, 8, 8, 8, 32)  0           ['batch_normalization_118[0][0]',
#                                                                   'batch_normalization_119[0][0]']
#
#  batch_normalization_120 (Batch  (None, 8, 8, 8, 32)  128        ['add_46[0][0]']
#  Normalization)
#
#  conv3d_124 (Conv3D)            (None, 8, 8, 8, 32)  27680       ['batch_normalization_120[0][0]']
#
#  batch_normalization_121 (Batch  (None, 8, 8, 8, 32)  128        ['conv3d_124[0][0]']
#  Normalization)
#
#  conv3d_125 (Conv3D)            (None, 8, 8, 8, 32)  27680       ['batch_normalization_121[0][0]']
#
#  conv3d_126 (Conv3D)            (None, 8, 8, 8, 32)  1056        ['batch_normalization_120[0][0]']
#
#  batch_normalization_122 (Batch  (None, 8, 8, 8, 32)  128        ['conv3d_125[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 8, 8, 8, 32)  128        ['conv3d_126[0][0]']
#  Normalization)
#
#  add_47 (Add)                   (None, 8, 8, 8, 32)  0           ['batch_normalization_122[0][0]',
#                                                                   'batch_normalization_123[0][0]']
#
#  batch_normalization_124 (Batch  (None, 8, 8, 8, 32)  128        ['add_47[0][0]']
#  Normalization)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 16, 16, 16,   27680      ['batch_normalization_124[0][0]']
#  spose)                         32)
#
#  batch_normalization_125 (Batch  (None, 16, 16, 16,   128        ['conv3d_transpose_3[0][0]']
#  Normalization)                 32)
#
#  activation_19 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_125[0][0]']
#                                 32)
#
#  add_48 (Add)                   (None, 16, 16, 16,   0           ['activation_19[0][0]',
#                                 32)                               'batch_normalization_114[0][0]']
#
#  batch_normalization_126 (Batch  (None, 16, 16, 16,   128        ['add_48[0][0]']
#  Normalization)                 32)
#
#  conv3d_130 (Conv3D)            (None, 16, 16, 16,   13840       ['batch_normalization_126[0][0]']
#                                 16)
#
#  batch_normalization_130 (Batch  (None, 16, 16, 16,   64         ['conv3d_130[0][0]']
#  Normalization)                 16)
#
#  conv3d_132 (Conv3D)            (None, 16, 16, 16,   13840       ['batch_normalization_126[0][0]']
#                                 16)
#
#  conv3d_131 (Conv3D)            (None, 16, 16, 16,   6928        ['batch_normalization_130[0][0]']
#                                 16)
#
#  batch_normalization_131 (Batch  (None, 16, 16, 16,   64         ['conv3d_132[0][0]']
#  Normalization)                 16)
#
#  add_49 (Add)                   (None, 16, 16, 16,   0           ['conv3d_131[0][0]',
#                                 16)                               'batch_normalization_131[0][0]']
#
#  conv3d_133 (Conv3D)            (None, 16, 16, 16,   6928        ['add_49[0][0]']
#                                 16)
#
#  batch_normalization_132 (Batch  (None, 16, 16, 16,   64         ['conv3d_133[0][0]']
#  Normalization)                 16)
#
#  conv3d_135 (Conv3D)            (None, 16, 16, 16,   6928        ['add_49[0][0]']
#                                 16)
#
#  conv3d_127 (Conv3D)            (None, 16, 16, 16,   13840       ['batch_normalization_126[0][0]']
#                                 16)
#
#  conv3d_134 (Conv3D)            (None, 16, 16, 16,   6928        ['batch_normalization_132[0][0]']
#                                 16)
#
#  batch_normalization_133 (Batch  (None, 16, 16, 16,   64         ['conv3d_135[0][0]']
#  Normalization)                 16)
#
#  batch_normalization_127 (Batch  (None, 16, 16, 16,   64         ['conv3d_127[0][0]']
#  Normalization)                 16)
#
#  add_50 (Add)                   (None, 16, 16, 16,   0           ['conv3d_134[0][0]',
#                                 16)                               'batch_normalization_133[0][0]']
#
#  conv3d_128 (Conv3D)            (None, 16, 16, 16,   6928        ['batch_normalization_127[0][0]']
#                                 16)
#
#  conv3d_136 (Conv3D)            (None, 16, 16, 16,   6928        ['add_50[0][0]']
#                                 16)
#
#  batch_normalization_128 (Batch  (None, 16, 16, 16,   64         ['conv3d_128[0][0]']
#  Normalization)                 16)
#
#  batch_normalization_134 (Batch  (None, 16, 16, 16,   64         ['conv3d_136[0][0]']
#  Normalization)                 16)
#
#  conv3d_138 (Conv3D)            (None, 16, 16, 16,   6928        ['add_50[0][0]']
#                                 16)
#
#  conv3d_129 (Conv3D)            (None, 16, 16, 16,   6928        ['batch_normalization_128[0][0]']
#                                 16)
#
#  conv3d_137 (Conv3D)            (None, 16, 16, 16,   6928        ['batch_normalization_134[0][0]']
#                                 16)
#
#  batch_normalization_135 (Batch  (None, 16, 16, 16,   64         ['conv3d_138[0][0]']
#  Normalization)                 16)
#
#  batch_normalization_129 (Batch  (None, 16, 16, 16,   64         ['conv3d_129[0][0]']
#  Normalization)                 16)
#
#  add_51 (Add)                   (None, 16, 16, 16,   0           ['conv3d_137[0][0]',
#                                 16)                               'batch_normalization_135[0][0]']
#
#  add_52 (Add)                   (None, 16, 16, 16,   0           ['batch_normalization_129[0][0]',
# ...
#                                 8)                                'batch_normalization_147[0][0]']
#
#  add_57 (Add)                   (None, 32, 32, 32,   0           ['batch_normalization_141[0][0]',
#                                 8)                                'add_56[0][0]']
#
#  add_34 (Add)                   (None, 64, 64, 64,   0           ['max_pooling3d_8[0][0]',
#                                 8)                                'max_pooling3d_9[0][0]']
#
#  batch_normalization_148 (Batch  (None, 32, 32, 32,   32         ['add_57[0][0]']
#  Normalization)                 8)
#
#  conv3d_151 (Conv3D)            (None, 64, 64, 64,   1736        ['add_34[0][0]']
#                                 8)
#
#  conv3d_transpose_5 (Conv3DTran  (None, 64, 64, 64,   1736       ['batch_normalization_148[0][0]']
#  spose)                         8)
#
#  batch_normalization_150 (Batch  (None, 64, 64, 64,   32         ['conv3d_151[0][0]']
#  Normalization)                 8)
#
#  conv3d_153 (Conv3D)            (None, 64, 64, 64,   1736        ['add_34[0][0]']
#                                 8)
#
#  batch_normalization_149 (Batch  (None, 64, 64, 64,   32         ['conv3d_transpose_5[0][0]']
#  Normalization)                 8)
#
#  conv3d_152 (Conv3D)            (None, 64, 64, 64,   1736        ['batch_normalization_150[0][0]']
#                                 8)
#
#  batch_normalization_151 (Batch  (None, 64, 64, 64,   32         ['conv3d_153[0][0]']
#  Normalization)                 8)
#
#  activation_21 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_149[0][0]']
#                                 8)
#
#  add_58 (Add)                   (None, 64, 64, 64,   0           ['conv3d_152[0][0]',
#                                 8)                                'batch_normalization_151[0][0]']
#
#  add_59 (Add)                   (None, 64, 64, 64,   0           ['activation_21[0][0]',
#                                 8)                                'add_58[0][0]']
#
#  conv3d_154 (Conv3D)            (None, 64, 64, 64,   868         ['add_59[0][0]']
#                                 4)
#
#  batch_normalization_152 (Batch  (None, 64, 64, 64,   16         ['conv3d_154[0][0]']
#  Normalization)                 4)
#
#  conv3d_156 (Conv3D)            (None, 64, 64, 64,   868         ['add_59[0][0]']
#                                 4)
#
#  conv3d_155 (Conv3D)            (None, 64, 64, 64,   436         ['batch_normalization_152[0][0]']
#                                 4)
#
#  batch_normalization_153 (Batch  (None, 64, 64, 64,   16         ['conv3d_156[0][0]']
#  Normalization)                 4)
#
#  add_60 (Add)                   (None, 64, 64, 64,   0           ['conv3d_155[0][0]',
#                                 4)                                'batch_normalization_153[0][0]']
#
#  conv3d_transpose_6 (Conv3DTran  (None, 128, 128, 12  436        ['add_60[0][0]']
#  spose)                         8, 4)
#
#  batch_normalization_154 (Batch  (None, 128, 128, 12  16         ['conv3d_transpose_6[0][0]']
#  Normalization)                 8, 4)
#
#  activation_22 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_154[0][0]']
#                                 8, 4)
#
#  add_61 (Add)                   (None, 128, 128, 12  0           ['activation_22[0][0]',
#                                 8, 4)                             'batch_normalization_86[0][0]']
#
#  batch_normalization_155 (Batch  (None, 128, 128, 12  16         ['add_61[0][0]']
#  Normalization)                 8, 4)
#
#  conv3d_160 (Conv3D)            (None, 128, 128, 12  436         ['batch_normalization_155[0][0]']
#                                 8, 4)
#
#  batch_normalization_159 (Batch  (None, 128, 128, 12  16         ['conv3d_160[0][0]']
#  Normalization)                 8, 4)
#
#  conv3d_162 (Conv3D)            (None, 128, 128, 12  436         ['batch_normalization_155[0][0]']
#                                 8, 4)
#
#  conv3d_161 (Conv3D)            (None, 128, 128, 12  436         ['batch_normalization_159[0][0]']
#                                 8, 4)
#
#  batch_normalization_160 (Batch  (None, 128, 128, 12  16         ['conv3d_162[0][0]']
#  Normalization)                 8, 4)
#
#  add_62 (Add)                   (None, 128, 128, 12  0           ['conv3d_161[0][0]',
#                                 8, 4)                             'batch_normalization_160[0][0]']
#
#  conv3d_163 (Conv3D)            (None, 128, 128, 12  436         ['add_62[0][0]']
#                                 8, 4)
#
#  batch_normalization_161 (Batch  (None, 128, 128, 12  16         ['conv3d_163[0][0]']
#  Normalization)                 8, 4)
#
#  conv3d_165 (Conv3D)            (None, 128, 128, 12  436         ['add_62[0][0]']
#                                 8, 4)
#
#  conv3d_157 (Conv3D)            (None, 128, 128, 12  436         ['batch_normalization_155[0][0]']
#                                 8, 4)
#
#  conv3d_164 (Conv3D)            (None, 128, 128, 12  436         ['batch_normalization_161[0][0]']
#                                 8, 4)
#
#  batch_normalization_162 (Batch  (None, 128, 128, 12  16         ['conv3d_165[0][0]']
#  Normalization)                 8, 4)
#
#  batch_normalization_156 (Batch  (None, 128, 128, 12  16         ['conv3d_157[0][0]']
#  Normalization)                 8, 4)
#
#  add_63 (Add)                   (None, 128, 128, 12  0           ['conv3d_164[0][0]',
#                                 8, 4)                             'batch_normalization_162[0][0]']
#
#  conv3d_158 (Conv3D)            (None, 128, 128, 12  436         ['batch_normalization_156[0][0]']
#                                 8, 4)
#
#  conv3d_166 (Conv3D)            (None, 128, 128, 12  436         ['add_63[0][0]']
#                                 8, 4)
#
#  batch_normalization_157 (Batch  (None, 128, 128, 12  16         ['conv3d_158[0][0]']
#  Normalization)                 8, 4)
#
#  batch_normalization_163 (Batch  (None, 128, 128, 12  16         ['conv3d_166[0][0]']
#  Normalization)                 8, 4)
#
#  conv3d_168 (Conv3D)            (None, 128, 128, 12  436         ['add_63[0][0]']
#                                 8, 4)
#
#  conv3d_159 (Conv3D)            (None, 128, 128, 12  436         ['batch_normalization_157[0][0]']
#                                 8, 4)
#
#  conv3d_167 (Conv3D)            (None, 128, 128, 12  436         ['batch_normalization_163[0][0]']
#                                 8, 4)
#
#  batch_normalization_164 (Batch  (None, 128, 128, 12  16         ['conv3d_168[0][0]']
#  Normalization)                 8, 4)
#
#  batch_normalization_158 (Batch  (None, 128, 128, 12  16         ['conv3d_159[0][0]']
#  Normalization)                 8, 4)
#
#  add_64 (Add)                   (None, 128, 128, 12  0           ['conv3d_167[0][0]',
#                                 8, 4)                             'batch_normalization_164[0][0]']
#
#  add_65 (Add)                   (None, 128, 128, 12  0           ['batch_normalization_158[0][0]',
#                                 8, 4)                             'add_64[0][0]']
#
#  batch_normalization_165 (Batch  (None, 128, 128, 12  16         ['add_65[0][0]']
#  Normalization)                 8, 4)
#
#  conv3d_transpose_7 (Conv3DTran  (None, 128, 128, 12  20         ['batch_normalization_165[0][0]']
#  spose)                         8, 4)
#
#  activation_23 (Activation)     (None, 128, 128, 12  0           ['conv3d_transpose_7[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 893,844
# Trainable params: 890,878
# Non-trainable params: 2,966
# __________________________________________________________________________________________________

# %%
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="Duck_&_IEG.hdf5",
                               verbose=1,
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=5,
                              min_delta=0.0001,
                              factor=0.2
                             )

# %%
history =  model.fit(training_generator,
                    epochs=10,
                    steps_per_epoch=len(train_ids),
                    callbacks= [checkpointer, reduce_lr, earlystopping],
                    validation_data = valid_generator
                    )
# Out:
# Epoch 1/10
# 6/6 [==============================] - ETA: 0s - loss: 1.9075 - accuracy: 0.2447 - mean_iou: 0.0671 - dice_coef: 0.1095
# Epoch 1: val_loss improved from inf to 9.89823, saving model to Duck_&_IEG.hdf5
# 6/6 [==============================] - 1132s 183s/step - loss: 1.9075 - accuracy: 0.2447 - mean_iou: 0.0671 - dice_coef: 0.1095 - val_loss: 9.8982 - val_accuracy: 0.2222 - val_mean_iou: 0.0588 - val_dice_coef: 0.0972 - lr: 0.0010
# Epoch 2/10
# 6/6 [==============================] - ETA: 0s - loss: 1.6307 - accuracy: 0.3657 - mean_iou: 0.0730 - dice_coef: 0.1175
# Epoch 2: val_loss improved from 9.89823 to 6.05599, saving model to Duck_&_IEG.hdf5
# 6/6 [==============================] - 1074s 180s/step - loss: 1.6307 - accuracy: 0.3657 - mean_iou: 0.0730 - dice_coef: 0.1175 - val_loss: 6.0560 - val_accuracy: 0.1251 - val_mean_iou: 0.0368 - val_dice_coef: 0.0650 - lr: 0.0010
# Epoch 3/10
# 6/6 [==============================] - ETA: 0s - loss: 1.4907 - accuracy: 0.5715 - mean_iou: 0.0746 - dice_coef: 0.1195
# Epoch 3: val_loss improved from 6.05599 to 4.48936, saving model to Duck_&_IEG.hdf5
# 6/6 [==============================] - 1070s 179s/step - loss: 1.4907 - accuracy: 0.5715 - mean_iou: 0.0746 - dice_coef: 0.1195 - val_loss: 4.4894 - val_accuracy: 0.1072 - val_mean_iou: 0.0344 - val_dice_coef: 0.0614 - lr: 0.0010
# Epoch 4/10
# 6/6 [==============================] - ETA: 0s - loss: 1.4118 - accuracy: 0.6791 - mean_iou: 0.0780 - dice_coef: 0.1241
# Epoch 4: val_loss improved from 4.48936 to 3.32975, saving model to Duck_&_IEG.hdf5
# 6/6 [==============================] - 1068s 179s/step - loss: 1.4118 - accuracy: 0.6791 - mean_iou: 0.0780 - dice_coef: 0.1241 - val_loss: 3.3297 - val_accuracy: 0.1821 - val_mean_iou: 0.0535 - val_dice_coef: 0.0899 - lr: 0.0010
# Epoch 5/10
# 6/6 [==============================] - ETA: 0s - loss: 1.3576 - accuracy: 0.7106 - mean_iou: 0.0822 - dice_coef: 0.1298
# Epoch 5: val_loss improved from 3.32975 to 2.50021, saving model to Duck_&_IEG.hdf5
# 6/6 [==============================] - 1065s 179s/step - loss: 1.3576 - accuracy: 0.7106 - mean_iou: 0.0822 - dice_coef: 0.1298 - val_loss: 2.5002 - val_accuracy: 0.2545 - val_mean_iou: 0.0691 - val_dice_coef: 0.1113 - lr: 0.0010
# Epoch 6/10
# 6/6 [==============================] - ETA: 0s - loss: 1.3020 - accuracy: 0.7444 - mean_iou: 0.0876 - dice_coef: 0.1372
# Epoch 6: val_loss improved from 2.50021 to 2.13325, saving model to Duck_&_IEG.hdf5
# 6/6 [==============================] - 1076s 181s/step - loss: 1.3020 - accuracy: 0.7444 - mean_iou: 0.0876 - dice_coef: 0.1372 - val_loss: 2.1333 - val_accuracy: 0.3833 - val_mean_iou: 0.0883 - val_dice_coef: 0.1361 - lr: 0.0010
# Epoch 7/10
# 6/6 [==============================] - ETA: 0s - loss: 1.2359 - accuracy: 0.7747 - mean_iou: 0.0941 - dice_coef: 0.1457
# Epoch 7: val_loss improved from 2.13325 to 1.97427, saving model to Duck_&_IEG.hdf5
# 6/6 [==============================] - 1066s 179s/step - loss: 1.2359 - accuracy: 0.7747 - mean_iou: 0.0941 - dice_coef: 0.1457 - val_loss: 1.9743 - val_accuracy: 0.5663 - val_mean_iou: 0.1176 - val_dice_coef: 0.1685 - lr: 0.0010
# Epoch 8/10
# 6/6 [==============================] - ETA: 0s - loss: 1.1719 - accuracy: 0.8270 - mean_iou: 0.1016 - dice_coef: 0.1554
# Epoch 8: val_loss did not improve from 1.97427
# 6/6 [==============================] - 1064s 179s/step - loss: 1.1719 - accuracy: 0.8270 - mean_iou: 0.1016 - dice_coef: 0.1554 - val_loss: 2.0184 - val_accuracy: 0.6642 - val_mean_iou: 0.1414 - val_dice_coef: 0.1917 - lr: 0.0010
# Epoch 9/10
# 6/6 [==============================] - ETA: 0s - loss: 1.1327 - accuracy: 0.8227 - mean_iou: 0.1107 - dice_coef: 0.1664
# Epoch 9: val_loss did not improve from 1.97427
# 6/6 [==============================] - 1068s 179s/step - loss: 1.1327 - accuracy: 0.8227 - mean_iou: 0.1107 - dice_coef: 0.1664 - val_loss: 2.3125 - val_accuracy: 0.6462 - val_mean_iou: 0.1404 - val_dice_coef: 0.1891 - lr: 0.0010
# Epoch 10/10
# 6/6 [==============================] - ETA: 0s - loss: 1.1074 - accuracy: 0.8525 - mean_iou: 0.1027 - dice_coef: 0.1554
# Epoch 10: val_loss did not improve from 1.97427
# 6/6 [==============================] - 1070s 180s/step - loss: 1.1074 - accuracy: 0.8525 - mean_iou: 0.1027 - dice_coef: 0.1554 - val_loss: 3.0463 - val_accuracy: 0.7017 - val_mean_iou: 0.1769 - val_dice_coef: 0.2222 - lr: 0.0010
