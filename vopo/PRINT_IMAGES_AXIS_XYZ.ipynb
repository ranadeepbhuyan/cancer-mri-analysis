# %% [markdown]
# <a href="https://colab.research.google.com/github/ranadeepbhuyan/cancer-mri-analysis/blob/main/vopo/PRINT_IMAGES_AXIS_XYZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import nibabel as nib
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Image sliced along x axis shown below:
#
# ---

# %%
data_path_x = r"/content/drive/MyDrive/PKG - UPENN-GBM NIFTI 3d to 2d exp 2/along x/patients-data"

# %%
image1x=nib.load(data_path_x + '/UPENN-GBM-Patients-19-slice180_x.nii').get_fdata()
image2x=nib.load(data_path_x + '/UPENN-GBM-Patients-19-slice160_x.nii').get_fdata()
image3x=nib.load(data_path_x + '/UPENN-GBM-Patients-19-slice060_x.nii').get_fdata()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20, 10))
slice_w = 45
ax1.imshow(image1x, cmap = 'gray')
ax1.set_title('along x axis slice number 180')
ax2.imshow(image2x, cmap = 'gray')
ax2.set_title('along x axis slice number 160')
ax3.imshow(image3x, cmap = 'gray')
ax3.set_title('along x axis slice number 60')
# Out:
# Text(0.5, 1.0, 'along x axis slice number 60')

# %% [markdown]
# Image sliced along y axis shown below:
#
# ---

# %%
data_path_y = r"/content/drive/MyDrive/PKG - UPENN-GBM NIFTI 3d to 2d exp 2/along y/patients data"

# %%
image1y=nib.load(data_path_y + '/UPENN-GBM-Patients-19-slice180_y.nii').get_fdata()
image2y=nib.load(data_path_y + '/UPENN-GBM-Patients-19-slice160_y.nii').get_fdata()
image3y=nib.load(data_path_y + '/UPENN-GBM-Patients-19-slice060_y.nii').get_fdata()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20, 10))
slice_w = 45
ax1.imshow(image1y, cmap = 'gray')
ax1.set_title('along y axis slice number 180')
ax2.imshow(image2y, cmap = 'gray')
ax2.set_title('along y axis slice number 160')
ax3.imshow(image3y, cmap = 'gray')
ax3.set_title('along y axis slice number 60')
# Out:
# Text(0.5, 1.0, 'along y axis slice number 60')

# %% [markdown]
# Image sliced along z axis shown below:
#
# ---

# %%
data_path_z = r"/content/drive/MyDrive/PKG - UPENN-GBM NIFTI 3d to 2d exp 2/along z/patients data"

# %%
image1z=nib.load(data_path_z + '/UPENN-GBM-Patients-00020-slice120_z.nii').get_fdata()
image2z=nib.load(data_path_z + '/UPENN-GBM-Patients-00020-slice080_z.nii').get_fdata()
image3z=nib.load(data_path_z + '/UPENN-GBM-Patients-00020-slice040_z.nii').get_fdata()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20, 10))
slice_w = 45
ax1.imshow(image1z, cmap = 'gray')
ax1.set_title('along z axis slice number 120')
ax2.imshow(image2z, cmap = 'gray')
ax2.set_title('along z axis slice number 80')
ax3.imshow(image3z, cmap = 'gray')
ax3.set_title('along z axis slice number 40')
# Out:
# Text(0.5, 1.0, 'along z axis slice number 40')
